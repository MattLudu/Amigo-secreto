# %% [markdown]
# <a href="https://colab.research.google.com/github/MattLudu/Amigo-secreto/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Numpy: Análisis numérico eficiente con Python**

# %% [markdown]
# NumPy es una biblioteca de Python que ofrece diversas herramientas y funcionalidades esenciales para la computación científica, incluyendo objetos de matriz multidimensional conocidos como *arrays*, rutinas para operaciones rápidas en matrizes, además de operaciones matemáticas, manipulación de formas, estadística entre otros. Es ampliamente utilizada en áreas como análisis de datos, procesamiento de señales y aprendizaje de máquina.
#
# Para acceder a la documentación de esta biblioteca, puedes hacer clic en el siguiente enlace: https://numpy.org/devdocs/index.html

# %%
import numpy as np

# %%
url = 'https://gist.githubusercontent.com/ahcamachod/41b8a65c5e5b58125401deafb68af460/raw/f84320f69efa1cc3e86e1db054422cfa4869c63e/manzanas.csv'

# %%
np.loadtxt(url , delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2697441631.py in <cell line: 0>()
# ----> 1 np.loadtxt(url , delimiter=',')
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_npyio_impl.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1379         delimiter = delimiter.decode('latin1')
#    1380
# -> 1381     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1382                 converters=converters, skiplines=skiprows, usecols=usecols,
#    1383                 unpack=unpack, ndmin=ndmin, encoding=encoding,
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_npyio_impl.py in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1019
#    1020         if read_dtype_via_object_chunks is None:
# -> 1021             arr = _load_from_filelike(
#    1022                 data, delimiter=delimiter, comment=comment, quote=quote,
#    1023                 imaginary_unit=imaginary_unit,
#
# ValueError: could not convert string '' to float64 at row 0, column 1.

# %%
7 * 12 + 3
#np.arange(1)

# %%
np.arange(1,88,1)

# %%
datos = np.loadtxt(url, delimiter=',', usecols = np.arange(1,88,1))

# %%
datos.ndim

# %%
datos.shape

# %%
datos.T

# %%
datos_transpuestos = datos.T

# %%
fechas = datos_transpuestos[:,0]
fechas

# %%
precios = datos_transpuestos[:,1:]
precios

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(fechas,precios)

# %%
plt.plot(fechas,precios[:,0])

# %%
fechas = np.arange(1,88,1)

# %%
plt.plot(fechas,precios[:,0])

# %%
Moscu = precios[:,0]
Kalinigrado = precios[:,1]
Petesburgo = precios[:,2]
Krasnodar = precios[:,3]
Ekaterinburgo = precios[:,4]

# %%
plt.plot(fechas,Kalinigrado)

# %%
Moscu.shape

# %%
moscu_1 = Moscu[0:12]
moscu_2 = Moscu[12:24]
moscu_3 = Moscu[24:36]
moscu_4 = Moscu[36:48]

# %%
plt.plot(np.arange(1,13,1),moscu_1)
plt.plot(np.arange(1,13,1),moscu_2)
plt.plot(np.arange(1,13,1),moscu_3)
plt.plot(np.arange(1,13,1),moscu_4)
plt.legend(['2013','2014','2015','2016'])

# %%
np.array_equal(moscu_1,moscu_2)
# Out:
# False

# %%
np.allclose(moscu_1,moscu_2,0.5)
# Out:
# True

# %%
np.mean(Moscu)
# Out:
# np.float64(98.79781609195402)

# %%
np.mean(Kalinigrado)
# Out:
# np.float64(74.5506896551724)

# %%
plt.plot(Kalinigrado)

# %%
np.isnan(Kalinigrado)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
np.sum(np.isnan(Kalinigrado))
# Out:
# np.int64(0)

# %%
(Kalinigrado[3] + Kalinigrado[5])/2
# Out:
# np.float64(49.17)

# %%
Kalinigrado[4] = (Kalinigrado[3] + Kalinigrado[5])/2

# %%
Kalinigrado
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,  49.17,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
plt.plot(fechas,Kalinigrado)

# %%
np.mean(Kalinigrado)
# Out:
# np.float64(74.5506896551724)

# %%
plt.plot(fechas,Moscu)

# %% [markdown]
# ### **y = ax + b**

# %%
x = fechas
y = 1.5 * x + 80

# %%
y
# Out:
# array([ 81.5,  83. ,  84.5,  86. ,  87.5,  89. ,  90.5,  92. ,  93.5,
#         95. ,  96.5,  98. ,  99.5, 101. , 102.5, 104. , 105.5, 107. ,
#        108.5, 110. , 111.5, 113. , 114.5, 116. , 117.5, 119. , 120.5,
#        122. , 123.5, 125. , 126.5, 128. , 129.5, 131. , 132.5, 134. ,
#        135.5, 137. , 138.5, 140. , 141.5, 143. , 144.5, 146. , 147.5,
#        149. , 150.5, 152. , 153.5, 155. , 156.5, 158. , 159.5, 161. ,
#        162.5, 164. , 165.5, 167. , 168.5, 170. , 171.5, 173. , 174.5,
#        176. , 177.5, 179. , 180.5, 182. , 183.5, 185. , 186.5, 188. ,
#        189.5, 191. , 192.5, 194. , 195.5, 197. , 198.5, 200. , 201.5,
#        203. , 204.5, 206. , 207.5, 209. , 210.5])

# %%
plt.plot(fechas,Moscu)
plt.plot(x,y)

# %%
Moscu - y
# Out:
# array([  -1.78,   -1.92,   -4.82,   -6.2 ,   -6.87,   -8.2 ,  -10.22,
#         -13.01,  -16.73,  -18.91,  -20.14,  -20.84,  -22.  ,  -21.97,
#         -22.22,  -23.95,  -27.39,  -30.1 ,  -30.82,  -33.95,  -35.97,
#         -39.61,  -36.14,  -26.84,  -12.07,  -14.18,  -19.35,  -23.37,
#         -23.54,  -27.71,  -27.86,  -23.74,  -26.87,  -32.36,  -35.33,
#         -35.91,  -32.43,  -26.74,  -27.66,  -27.72,  -30.4 ,  -32.94,
#         -30.8 ,  -33.12,  -45.42,  -53.46,  -59.17,  -62.01,  -62.06,
#         -61.49,  -62.9 ,  -64.22,  -60.59,  -39.24,  -32.9 ,  -36.1 ,
#         -50.95,  -65.12,  -69.41,  -66.65,  -64.92,  -65.  ,  -59.55,
#         -54.83,  -55.02,  -51.42,  -48.61,  -52.64,  -79.24,  -91.55,
#         -93.57,  -91.85,  -90.4 ,  -88.  ,  -89.19,  -90.99,  -88.13,
#         -80.09,  -73.21,  -76.06,  -88.47, -100.81, -106.67, -104.93,
#        -104.06, -100.77, -100.22])

# %%
np.sqrt(np.sum(np.power(Moscu-y,2)))
# Out:
# np.float64(516.150824953327)

# %%
x = fechas
y = 0.5 * x + 80

# %%
plt.plot(fechas,Moscu)
plt.plot(x,y)

# %%
Moscu-y
# Out:
# array([ -0.78,   0.08,  -1.82,  -2.2 ,  -1.87,  -2.2 ,  -3.22,  -5.01,
#         -7.73,  -8.91,  -9.14,  -8.84,  -9.  ,  -7.97,  -7.22,  -7.95,
#        -10.39, -12.1 , -11.82, -13.95, -14.97, -17.61, -13.14,  -2.84,
#         12.93,  11.82,   7.65,   4.63,   5.46,   2.29,   3.14,   8.26,
#          6.13,   1.64,  -0.33,   0.09,   4.57,  11.26,  11.34,  12.28,
#         10.6 ,   9.06,  12.2 ,  10.88,  -0.42,  -7.46, -12.17, -14.01,
#        -13.06, -11.49, -11.9 , -12.22,  -7.59,  14.76,  22.1 ,  19.9 ,
#          6.05,  -7.12, -10.41,  -6.65,  -3.92,  -3.  ,   3.45,   9.17,
#          9.98,  14.58,  18.39,  15.36, -10.24, -21.55, -22.57, -19.85,
#        -17.4 , -14.  , -14.19, -14.99, -11.13,  -2.09,   5.79,   3.94,
#         -7.47, -18.81, -23.67, -20.93, -19.06, -14.77, -13.22])

# %%
np.sum(np.power(Moscu - y, 2))
# Out:
# np.float64(11485.094100000002)

# %%
 np.sqrt(np.sum(np.power(Moscu-y,2)))
# Out:
# np.float64(107.16853129533875)

# %%
np.linalg.norm(Moscu-y)
# Out:
# np.float64(107.16853129533875)
